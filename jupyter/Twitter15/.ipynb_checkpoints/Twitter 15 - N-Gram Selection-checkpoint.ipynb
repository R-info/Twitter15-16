# %%
import sys
sys.path.insert(1, '../..')

import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../../data/processed/twitter15_dataset_with_tvt.csv", lineterminator="\n")
data.head()
# Out:
#              tweet_id                                         tweet_text  \
# 0  731166399389962242  🔥ca kkk grand wizard 🔥 endorses @hillaryclinto...
# 1  714598641827246081  an open letter to trump voters from his top st...
# 2  691809004356501505  america is a nation of second chances —@potus ...
# 3  693204708933160960  brandon marshall visits and offers advice, sup...
# 4  551099691702956032  rip elly may clampett: so sad to learn #beverl...
#
#         label       tvt  cv_fold        tt      tvt2
# 0  unverified  training        1  training  testting
# 1  unverified  training        1      test  training
# 2   non-rumor  training        2  training  training
# 3   non-rumor  training        1  training  training
# 4        true  training        3  training  training

# %%
bigram_data = pd.read_excel('../../data/processed/twitter15_ngram_distribution.xlsx', sheet_name='bigram')
bigram_data.columns = ["token", "unverified", "non-rumor", "true", "false"]
bigram_data.head()
# Out:
#                       token  unverified  non-rumor  true  false
# 0                    ca kkk           1          0     0      0
# 1                 kkk grand           1          0     0      0
# 2              grand wizard           1          0     0      0
# 3           wizard endorses           1          0     0      0
# 4  endorses @hillaryclinton           1          0     0      0

# %%
bigram_vector_base = bigram_data['token'].tolist()
print(len(bigram_vector_base))
bigram_vector_base[10]
# Out:
# 13842
# 'to trump'

# %%
label_rnr = []
for i, d in data.iterrows():
    if d['label'] == "non-rumor":
        label_rnr.append("non-rumours")
    else:
        label_rnr.append("rumours")
        
data['label_rnr'] = pd.Series(label_rnr)
data.head()
# Out:
#              tweet_id                                         tweet_text  \
# 0  731166399389962242  🔥ca kkk grand wizard 🔥 endorses @hillaryclinto...
# 1  714598641827246081  an open letter to trump voters from his top st...
# 2  691809004356501505  america is a nation of second chances —@potus ...
# 3  693204708933160960  brandon marshall visits and offers advice, sup...
# 4  551099691702956032  rip elly may clampett: so sad to learn #beverl...
#
#         label       tvt  cv_fold        tt      tvt2    label_rnr
# 0  unverified  training        1  training  testting      rumours
# 1  unverified  training        1      test  training      rumours
# 2   non-rumor  training        2  training  training  non-rumours
# 3   non-rumor  training        1  training  training  non-rumours
# 4        true  training        3  training  training      rumours

# %%
# labels_str = ['rumour', 'non-rumour']
label_type = "label_rnr"
labels_str = data[label_type].unique().tolist()
labels_str
# Out:
# ['unverified', 'non-rumor', 'true', 'false']

# %%
labels = []
for i, d in data.iterrows():
    lab = labels_str.index(d[label_type])
    labels.append(lab)
labels[:10]
# Out:
# [0, 0, 1, 1, 2, 1, 0, 2, 0, 3]

# %%
import string
import nltk
from nltk.tokenize import TweetTokenizer

tokenizer = TweetTokenizer(reduce_len=True)

def text2bigrams(text):
    bigrams = tokenizer.tokenize(text.encode('ascii', 'ignore').decode('utf8'))
    bigrams = [t for t in bigrams if t not in string.punctuation]
    bigrams = [t for t in bigrams if t not in ['URL', '‘', '’']]
    
    bigrams = nltk.bigrams(bigrams)
    bigrams = map(' '.join, bigrams)
    bigrams = [bgr for bgr in bigrams]
    
    return bigrams


def bigrams_vectors_generation(texts):
    bigram_vectors = []
    for text in texts:
        bigrams = text2bigrams(text)

        init_vec = [0.0 for _ in range(len(bigram_vector_base) + 1)]
        for bgr in bigrams:
            if bgr in bigram_vector_base:
                idx = bigram_vector_base.index(bgr)
                init_vec[idx] = 1.0
            else:
                init_vec[-1] = 1.0
        bigram_vectors.append(init_vec)
    
    return bigram_vectors

# %%
texts = data['tweet_text'].tolist()
vectors = bigrams_vectors_generation(texts)

# %%
train_vectors = np.array([vectors[i] for i, d in data.iterrows() if d['tvt2'] == 'training'])
val_vectors = np.array([vectors[i] for i, d in data.iterrows() if d['tvt2'] == 'validation'])
test_vectors = np.array([vectors[i] for i, d in data.iterrows() if d['tvt2'] == 'testting'])

train_labels = np.array([labels[i] for i, d in data.iterrows() if d['tvt2'] == 'training'])
val_labels = np.array([labels[i] for i, d in data.iterrows() if d['tvt2'] == 'validation'])
test_labels = np.array([labels[i] for i, d in data.iterrows() if d['tvt2'] == 'testting'])

# %%
from sklearn.svm import LinearSVC

from library.classification import SKLearnClassification
from library.evaluation import ConfusionMatrix

svm = LinearSVC()

model = SKLearnClassification(svm, "Support Vector Machine")
print(f"\n--- START ---")
model.train(train_vectors, train_labels, "Twitter15")

print("Validation Set")
preds = model.predict(val_vectors)

conf_mat = ConfusionMatrix(
    labels=val_labels,
    predictions=preds,
    binary=True
)
conf_mat.evaluate()

print("--- END ---\n")
# Out:
# --- START ---
# ---> execution time : 0.07 seconds
# Validation Set
# Binary Class Evaluation
#
# True Positive : 78
# False Positive : 70
# False Negative : 140
# True Negative : 59
#
# Class positive Evaluation
# - Precision : 52.703 %
# - Recall : 35.78 %
# - F1 : 0.42623
#
# Class negative Evaluation
# - Precision : 29.648 %
# - Recall : 45.736 %
# - F1 : 0.35976
#
# Combined Evaluation
# - Accuracy : 39.481 %
# - Precision : 41.175 %
# - Recall : 40.758 %
# - F1 : 0.40965
# - Average Confidence : 214.12 %
# Model, Combined,,,,positive,,,negative,,,
# Anonymous, 39.481, 41.175, 40.758, 0.40965, 52.703, 35.78, 0.42623, 29.648, 45.736, 0.35976,
# --- END ---

# %%
from scipy.sparse import csr_matrix

coefs = model.model.coef_
if type(coefs) == csr_matrix:
    coefs.toarray().tolist()[0]
else:
    coefs.tolist()
coefs_and_features = list(zip(coefs[0], bigram_vector_base))

# Most predictive overall
coefs_and_features = sorted(coefs_and_features, key=lambda x: abs(x[0]), reverse=True)
print(f"Total tokens : {len(coefs_and_features)}")
# Out:
# Total tokens : 13842

# %%
coefs.shape
# Out:
# (4, 13843)

# %%
coefs_and_features
# Out:
# [(0.5250678303533886, 'bathroom policy'),
#  (0.5030535689520111, 'hands up'),
#  (0.49426810156595513, 'wounded in'),
#  (0.4540666680022467, '5p hell'),
#  (0.4540666680022467, 'hell no'),
#  (0.4540666680022467, 'no #5pbagcharge'),
#  (0.4105571846394519, 'bernie sanders'),
#  (0.39782016719516944, '#ferguson police'),
#  (0.3893032727465719, 'institutional racism'),
#  (0.38762720167561876, 'transgender bathroom'),
#  (0.37326304525782167, 'about the'),
#  (0.3538870435899357, 'bag charge'),
#  (0.349513178953573, 'sports illustrated'),
#  (0.3481925323204874, 'leader al-baghdadi'),
#  (0.3425746869898935, "nancy reagan's"),
#  (0.33728738148080095, 'hillary clinton'),
#  (0.3363209217485897, 'who shot'),
#  (0.33450722569756663, '#ferguson pd'),
#  (0.3304725861518524, 'of vegetarians'),
#  (0.3304725861518524, 'eat meat'),
#  (0.326968296197526, 'was a'),
#  (0.31563805970772024, 'afghan woman'),
#  (0.3082399026442756, '@target stock'),
#  (0.2969079792776175, 'chemical weapons'),
#  (0.2967326179880784, 'causes of'),
#  (0.29598269744567884, 'nude for'),
#  (0.2889515174059068, 'local school'),
#  (0.2889515174059068, 'school art'),
#  (0.2889515174059068, 'art project'),
#  (0.2889515174059068, 'project titled'),
#  (0.2889515174059068, 'titled candlelight'),
#  (0.2889515173035115, '#sydneysiege latest'),
#  (0.2889515173035115, 'latest video'),
#  (0.2889515173035115, 'video of'),
#  (0.2889515173035115, 'of hostages'),
#  (0.2889515173035115, 'hostages escaping'),
#  (0.28299661691745814, 'from police'),
#  (0.27714148447059456, 'christian bale'),
#  (0.27714148447059456, 'play steve'),
#  (0.27714148447059456, 'steve jobs'),
#  (-0.2757896918292018, 'paul walker'),
#  (0.2754686646468989, 'from ottawa'),
#  (0.2745575499551401, "reagan's funeral"),
#  (0.2745214351506629, '5p bag'),
#  (0.2745214351506629, 'charge fi'),
#  (0.2745214351506629, 'fi dead'),
#  (0.2745214351506629, 'dead #robthisengland'),
#  (-0.27384495570755274, 'happy #lefthandersday'),
#  (-0.2738445946925512, 'report spider'),
#  (-0.2738444638465569, 'happy #gossipgirlday'),
#  (-0.27384443807503117, 'happy #nationalhugday'),
#  (-0.2738444332884312, 'happy #nationalchocolatecakeday'),
#  (0.27215035011897903, "up don't"),
#  (0.27215035011897903, "don't shoot"),
#  (0.26900657599368016, 'payments to'),
#  (0.26900657599368016, 'to hard'),
#  (0.26900657599368016, 'hard drive'),
#  (0.26900657599368016, 'destruction company'),
#  (0.2670011007077182, 'hong kong'),
#  (0.2658408932898224, 'shooter was'),
#  (0.2649822643661078, 'at dulles'),
#  (0.2630436997008804, 'punishment for'),
#  (0.2585950979336275, 'ios 8'),
#  (0.2563722263435552, 'pose nude'),
#  (0.2563584870407426, '25 taliban'),
#  (0.25560567223746244, '#tcot #pjnet'),
#  (0.25426566525277045, 'from his'),
#  (0.25426566525277045, 'his top'),
#  (0.24825108481423797, 'homemade hazmat'),
#  (0.24724139796303207, 'the police'),
#  (0.2465208979700819, 'suicide note'),
#  (0.2465208979700819, 'note on'),
#  (0.2465208979700819, 'on tumblr'),
#  (0.24555004664061655, 'has won'),
#  (0.24513337358032974, 'calls for'),
#  (0.24449736439038217, 'isis militants'),
#  (0.24449736439038217, 'militants are'),
#  (0.24449736439038217, 'are beheading'),
#  (0.24449736439038217, 'beheading their'),
#  (0.24449736439038217, 'their own'),
#  (0.24449736439038217, 'own fighters'),
#  (0.2434923446749043, 'islamic state'),
#  (0.2401114612323655, 'victoria woodhull'),
#  (0.23986054913755472, 'stock sinks'),
#  (0.23986054913755472, '1.5 billion'),
#  (0.23764494693905108, 'landmarks across'),
#  (0.23605859671811846, 'isis leader'),
#  (0.2323961013932958, 'skipping nancy'),
#  (0.23090321883303352, 'up dont'),
#  (0.23090321883303352, 'dont shoot'),
#  (0.23049749260780303, 'kills 25'),
#  (0.22858474234303727, 'shocked by'),
#  (0.22828870732596537, 'trump goes'),
#  (0.22705882288615792, 'of people'),
#  (0.22697428988369112, 'iraqi officials'),
#  (0.22596359371041413, 'top strategist-turned-defector'),
#  (0.22553512170029416, 'sanders speaking'),
#  (0.22553512170029416, 'speaking about'),
#  (0.22553512170029416, 'about institutional'),
#  (0.22119375216805662, 'parliament hill'),
#  (0.22073242771886586, 'air strike'),
#  (0.2201516134426747, 'the #ferguson'),
#  (0.21967160205583458, 'suspect in'),
#  (0.21960964307887954, 'laziness is'),
#  (0.21960964307887954, 'a trait'),
#  (0.21960964307887954, 'trait in'),
#  (0.21864341033275972, 'up in'),
#  (0.21797539337379046, 'nancy reagans'),
#  (0.21797539337379046, 'reagans funeral'),
#  (0.21797539337379046, 'bachmann obama'),
#  (0.21797539337379046, 'obama classless'),
#  (0.21797539337379046, 'classless for'),
#  (0.21797539337379046, 'missing nancy'),
#  (0.21696649179911592, 'for flight'),
#  (0.21651676593149372, 'report christian'),
#  (0.21651676593149372, 'bale will'),
#  (0.21651676593149372, 'will play'),
#  (-0.2159904430973555, "paul walker's"),
#  (0.2152134849807354, 'death in'),
#  (0.21433306912463013, 'a democrat'),
#  (0.21361329232813714, 'release of'),
#  (0.21191213659729513, 'niagara falls'),
#  (0.21191213659729513, 'falls turned'),
#  (0.21191213659729513, 'turned purple'),
#  (0.21191213659729513, 'purple on'),
#  (0.21191213659729513, 'day prince'),
#  (0.21191213659729513, 'prince died'),
#  (0.21158465397602355, 'donald trump'),
#  (0.21078823253539114, 'drive destruction'),
#  (0.21022757943959938, 'bob beckel'),
#  (0.21022757943959938, 'julian assange'),
#  (0.21013342941980262, 'open letter'),
#  (0.20917044635868026, 'on parliament'),
#  (0.2073803905264919, 'the #orlando'),
#  (0.20706367582114887, 'black men'),
#  (0.20706367582114887, 'to run'),
#  (0.20706367582114887, 'run from'),
#  (0.20674586648048876, 'officer who'),
#  (0.2062862677840305, 'surprising number'),
#  (0.2062862677840305, 'number of'),
#  (0.2062862677840305, 'vegetarians secretly'),
#  (0.2062862677840305, 'secretly eat'),
#  (0.20414991700175744, 'police release'),
#  (0.2028417448356611, 'for sports'),
#  (0.2023194946372653, 'of death'),
#  (0.2022289899420789, 'to skip'),
#  (0.20173114728852418, 'sanders has'),
#  (0.20161253974288657, 'company ...'),
#  (0.19995181262301778, 'in 2016'),
#  (-0.19873946613200089, 'to the'),
#  (0.19859426334692337, 'is 19'),
#  (0.1983068350338565, 'with down'),
#  (0.1983068350338565, 'down syndrome'),
#  (0.19666607321206128, 'police officer'),
#  (0.19630612176611087, 'won the'),
#  (0.19559413539620385, 'according to'),
#  (0.1937657922479571, 'mike brown'),
#  (0.19043424329657424, 'canadian teen'),
#  (0.19043424329657424, "teen didn't"),
#  (0.19043424329657424, "didn't find"),
#  (0.19043424329657424, 'find a'),
#  (0.19043424329657424, 'a lost'),
#  (0.19043424329657424, 'lost mayan'),
#  (0.19043424329657424, 'mayan city'),
#  (0.18978673451037487, 'may have'),
#  (0.18972426853811458, 'abu bakr'),
#  (0.18696865357188375, 'sydney opera'),
#  (0.18696865357188375, 'opera house'),
#  (0.18696865357188375, 'house evacuated'),
#  (0.18696865357188375, 'evacuated concourse'),
#  (0.18696865357188375, 'concourse deserted'),
#  (0.18696865357188375, 'deserted #sydneysiege'),
#  (0.18696865357188375, '#sydneysiege via'),
#  (0.18696865357188375, 'via @cberkman'),
#  (0.18670080494122404, 'the street'),
#  (0.18567392222798867, 'officials say'),
#  (0.18530366284683342, 'passenger at'),
#  (0.18530366284683342, 'hazmat suit'),
#  (0.18526793541821035, 'icloud drive'),
#  (0.18526793541821035, 'drive documents'),
#  (0.18506644531119598, 'time to'),
#  (0.18393596609550636, 'have been'),
#  (0.18378795493129427, 'has been'),
#  (0.18338018982240473, 'a tweet'),
#  (0.18338018982240473, 'tweet from'),
#  (0.18338018982240473, 'from @realdonaldtrump'),
#  (0.18338018982240473, '@realdonaldtrump about'),
#  (0.18338018982240473, '#orlando shooting'),
#  (0.1817869140758036, '8 bug'),
#  (0.1817869140758036, 'your icloud'),
#  (0.18159863811412869, 'kevin vickers'),
#  (0.18041021135533558, 'over transgender'),
#  (0.18021016913744647, 'target boycott'),
#  (0.1788341767820094, '#mikebrown was'),
#  (0.17714585374591096, 'an open'),
#  (0.17676393733341172, 'in #ferguson'),
#  (0.17589384797375907, 'kim jong'),
#  (0.17589384797375907, 'jong un'),
#  (0.17555752373310454, 'abdel-majed abdel'),
#  (0.17555752373310454, 'abdel bary'),
#  (0.1748780914399567, 'not the'),
#  (0.17483004232473676, 'woman kills'),
#  (0.17475668747335016, 'centre block'),
#  (0.1743520360253742, 'a robbery'),
#  (-0.17354486122902305, 'killed in'),
#  (-0.17252002740679162, 'las vegas'),
#  (0.1723934181589897, 'for missing'),
#  (0.17107216475799625, 'an unarmed'),
#  (0.17079927396650404, 'stock plunges'),
#  (0.17079927396650404, 'plunges in'),
#  (0.17079927396650404, 'in early'),
#  (0.17079927396650404, 'early days'),
#  (0.17079927396650404, 'days of'),
#  (0.17079927396650404, 'of @americanfamassc'),
#  (0.17079927396650404, '@americanfamassc boycott'),
#  (0.16884337670603664, 'al-baghdadi wounded'),
#  (0.16812900004930856, 'women who'),
#  (0.16753314362747168, 'tiger with'),
#  (0.1672877311403482, 'pathetic little'),
#  (0.1672877311403482, 'little twat'),
#  (0.1672877311403482, 'twat cant'),
#  (0.1672877311403482, 'cant wait'),
#  (0.1672877311403482, 'wait to'),
#  (0.1672877311403482, 'to argue'),
#  (0.1672877311403482, 'argue over'),
#  (0.1672877311403482, 'over 5p'),
#  (0.1672877311403482, '5p bagcharge'),
#  (0.16728766646255977, 'poster girl'),
#  (0.16728766646255977, 'girl for'),
#  (0.16728766646255977, 'for kobane'),
#  (0.16728766646255977, 'kobane resistance'),
#  (0.16728766646255977, 'resistance reportedly'),
#  (0.16728766646255977, 'reportedly beheaded'),
#  (0.16728766646255977, 'beheaded sickening'),
#  (0.16728766646255977, 'sickening #rehana'),
#  (0.16728766646255977, '#rehana #kobane'),
#  (0.16635080593002902, 'jihadi john'),
#  (0.1644315238608144, 'in blacks'),
#  (0.16437896435854227, 'to attend'),
#  (0.16437896435854227, 'obama skipping'),
#  (0.16437896435854227, 'funeral to'),
#  (0.16437896435854227, 'attend sxsw'),
#  (-0.16430666710526162, 'oooh my'),
#  (-0.16430666710526162, 'my d-rose'),
#  (-0.16430661925974052, '#mh17 14'),
#  (-0.16430661925974052, '14 ..'),
#  (0.16293801005446396, 'in nevada'),
#  (0.16285171003630222, 'news target'),
#  (0.16285171003630222, 'target stock'),
#  (0.16285171003630222, 'stock plummets'),
#  (0.16285171003630222, 'plummets #lbgtq'),
#  (0.16285171003630222, '#lbgtq #bathroombill'),
#  (0.16285171003630222, '#bathroombill #tcot'),
#  (0.16285171003630222, '#pjnet #rednationrising'),
#  (0.16097633254868904, 'a canadian'),
#  (-0.16038890612023932, 'iphone 6'),
#  (0.157443836895657, 'stock has'),
#  (0.157443836895657, 'taken a'),
#  (0.15687455800904226, 'more official'),
#  (-0.15598126994307734, 'more than'),
#  (0.1556317093356464, '#ferguson cops'),
#  (0.15535011918376665, 'un broke'),
#  (0.15535011918376665, 'his ankles'),
#  (0.15535011918376665, 'ankles because'),
#  (0.15535011918376665, "he's too"),
#  (0.15535011918376665, 'too fat'),
#  (0.15535011918376665, 'fat ...'),
#  (0.15518799471340639, '2.5 billion'),
#  (0.15518799471340639, 'billion hit'),
#  (0.15341445655513902, 'for bleeding'),
#  (0.15341445655513902, 'bleeding on'),
#  (0.15288225054173735, 'the nevada'),
#  (0.15288225054173735, 'nevada caucus'),
#  (0.15288225054173735, 'caucus #nvcaucus'),
#  (0.1527807106288377, 'released this'),
#  (0.15203887379734424, 'caitlyn jenner'),
#  (0.15169574734806907, 'in airstrike'),
#  (0.15162033837084535, 'the press'),
#  (0.15135556849246107, '#sydneysiege hostage-takers'),
#  (0.15135556849246107, 'hostage-takers have'),
#  (0.15135556849246107, 'have suicide'),
#  (0.15135556849246107, 'suicide belts'),
#  (0.15135556849246107, 'belts demand'),
#  (0.15135556849246107, 'demand radio'),
#  (0.15135556849246107, 'radio convo'),
#  (0.15135556849246107, 'convo with'),
#  (0.15135556849246107, 'with #abbott'),
#  (0.15135556849246107, '#abbott report'),
#  (0.15135555209679438, 'spider burrows'),
#  (0.15135555209679438, 'burrows through'),
#  (0.15135555209679438, "through man's"),
#  (0.15135555209679438, "man's appendix"),
#  (0.15135555209679438, 'appendix scar'),
#  (0.15135555209679438, 'scar and'),
#  (0.15135555209679438, 'and crawls'),
#  (0.15135555209679438, 'crawls under'),
#  (0.15135555209679438, 'under his'),
#  (0.15135555209679438, 'his skin'),
#  (0.15135555203906984, 'the big'),
#  (0.15135555203906984, 'big one'),
#  (0.15135555203906984, 'one large'),
#  (0.15135555203906984, 'large scale'),
#  (0.15135555203906984, 'scale motion'),
#  (0.15135555203906984, 'motion detected'),
#  (0.15135555203906984, 'detected along'),
#  (0.15135555203906984, 'along san'),
#  (0.15135555203906984, 'san andreas'),
#  (0.15135555203906984, 'andreas fault'),
#  (0.15135552034816033, 'perfect photos'),
#  (0.15135552034816033, 'photos even'),
#  (0.15135552034816033, 'even at'),
#  (0.15135552034816033, 'at 30'),
#  (0.15135552034816033, '30 mph'),
#  (0.15135552034816033, 'mph with'),
#  (0.15135552034816033, 'with optical'),
#  (0.15135552034816033, 'optical image'),
#  (0.15135552034816033, 'image stabilization'),
#  (0.15135552034816033, 'stabilization #galaxynote4'),
#  (0.15113397055202063, 'suspects in'),
#  (0.15113397055202063, 'in #charliehebdo'),
#  (0.15103394946062626, 'threatened to'),
#  (0.15103394946062626, 'to kill'),
#  (-0.15082144192317487, 'shot down'),
#  (0.15040247425514286, 'unarmed kid'),
#  (0.1503111387184562, 'well this'),
#  (0.14964510029559394, 'concerned airport'),
#  (0.14964510029559394, 'airport passenger'),
#  (0.14964510029559394, 'passenger suits'),
#  (0.14964510029559394, 'suits up'),
#  (0.14964510029559394, 'in homemade'),
#  (0.14964510029559394, 'hazmat before'),
#  (0.14964510029559394, 'before flight'),
#  (0.14857726861712167, 'registered democrat'),
#  (0.14844489416357337, 'actually won'),
#  (0.14844489416357337, 'won nevada'),
#  (0.14787460542822378, '#orlando oh'),
#  (0.14787460542822378, 'oh look'),
#  (0.14787460542822378, 'look the'),
#  (0.14787460542822378, 'the muslim'),
#  (0.14787460542822378, 'muslim shooter'),
#  (0.14787460542822378, 'was also'),
#  (0.14787460542822378, 'also a'),
#  (0.1471816335922228, 'if police'),
#  (-0.14718152737142354, 'to parents'),
#  (0.14674601773443238, 'shooting gunmen'),
#  (0.14674601773443238, 'gunmen shouted'),
#  (0.14674601773443238, 'shouted we'),
#  (0.14674601773443238, 'have avenged'),
#  (0.14674601773443238, 'avenged the'),
#  (0.14674601773443238, 'the prophet'),
#  (0.14674601773443238, 'prophet during'),
#  (0.14674601773443238, 'during attack'),
#  (0.14674601773443238, 'attack reports'),
#  (-0.14630236457766452, 'shot at'),
#  (0.14598679328621667, 'to @realdonaldtrump'),
#  (0.14598679328621667, '@realdonaldtrump from'),
#  (-0.14590872323492965, 'response to'),
#  (0.14490137566484151, 'a muslim'),
#  (0.14449143728515657, 'witness tells'),
#  (0.14449143728515657, 'tells #cbcnews'),
#  (0.14449143728515657, '#cbcnews suspected'),
#  (0.14449143728515657, 'suspected shooter'),
#  (0.14449143728515657, 'shooter of'),
#  (0.14449143728515657, 'of uniformed'),
#  (0.14449143728515657, 'memorial was'),
#  (0.14449143728515657, 'carrying rifle'),
#  (0.14362128787455686, 'form of'),
#  (0.1432838402496827, 'statement from'),
#  (0.1432838402496827, 'hospital received'),
#  (0.1432838402496827, 'received 3'),
#  (0.1432838402496827, '3 patients'),
#  (0.1432838402496827, 'patients 2'),
#  (0.1432838402496827, '2 in'),
#  (0.1432838402496827, 'in stable'),
#  (0.1432838402496827, 'stable condition'),
#  (0.14294908208207577, 'shoot hong'),
#  (0.14294908208207577, 'kong edition'),
#  (-0.1422112558814135, 'mountain dew'),
#  (0.1420992173319229, 'assassination of'),
#  (0.1420992173319229, 'of julian'),
#  (0.1420992173319229, 'hillary surroagte'),
#  (0.1420992173319229, 'surroagte bob'),
#  (0.1420992173319229, 'beckel calls'),
#  (0.1420992173319229, 'for assassination'),
#  (0.14169133724991795, 'leader abu'),
#  (0.14169133724991795, 'bakr al-baghdadi'),
#  (0.14165242202035588, 'transgender teen'),
#  (0.14124355393526744, 'isis executioner'),
#  (0.14124355393526744, 'executioner jihadi'),
#  (0.14124355393526744, 'in air'),
#  (0.14105384680465619, 'attack suspects'),
#  (0.14105384680465619, 'suspects have'),
#  (0.14105384680465619, 'have reportedly'),
#  (0.14105384680465619, 'reportedly fired'),
#  (0.14105384680465619, 'fired shots'),
#  (0.14105384680465619, 'shots while'),
#  (0.14105384680465619, 'while robbing'),
#  (0.14105384680465619, 'robbing a'),
#  (0.14105384680465619, 'a petrol'),
#  (0.14018643858024996, 'developing story'),
#  (0.14018643858024996, 'parliament soldier'),
#  (0.14018643858024996, 'shot gunman'),
#  (0.14018643858024996, 'gunman on'),
#  (0.14018643858024996, 'loose follow'),
#  (0.14018643858024996, 'follow our'),
#  (0.14018643858024996, 'our developing'),
#  (0.13977741513582398, 'more officials'),
#  (0.13977741513582398, 'they do'),
#  (0.13977741513582398, 'know the'),
#  (0.13977741513582398, 'the extent'),
#  (0.13977741513582398, 'extent of'),
#  (0.13977741513582398, "of al-baghdadi's"),
#  (0.13977741513582398, "al-baghdadi's apparent"),
#  (0.13977741513582398, 'apparent injuries'),
#  (0.13877150361776247, 'human dna'),
#  (0.13877150361776247, 'in hot'),
#  (0.13877150361776247, 'hot dogs'),
#  (0.13877150361776247, 'dna found'),
#  (0.13877150361776247, 'dogs and'),
#  (0.13877150361776247, 'and 10'),
#  (0.13877150361776247, '10 of'),
#  (0.13877150361776247, 'of vegetarian'),
#  (0.13877150361776247, 'vegetarian sausages'),
#  (0.13877150361776247, 'sausages contain'),
#  (0.13877150361776247, 'contain meat'),
#  (0.13870496702479146, 'obama cuts'),
#  (0.13870496702479146, 'cuts military'),
#  (0.13870496702479146, 'military pay'),
#  (0.13870496702479146, 'year in'),
#  (0.13870496702479146, 'a row'),
#  (0.13843526729559652, '@caitlyn_jenner will'),
#  (0.13843526729559652, 'will reportedly'),
#  (0.13843526729559652, 'reportedly pose'),
#  (0.1381942253485741, 'hillary overcharges'),
#  (0.1381942253485741, 'overcharges poorest'),
#  (0.1381942253485741, 'poorest campaign'),
#  (0.1381942253485741, 'campaign donors'),
#  (0.1381942253485741, 'donors @lindasuhler'),
#  (0.1381942253485741, '@lindasuhler @realdrgina'),
#  (0.1381942253485741, '@realdrgina @girlsfortrump'),
#  (0.1381942253485741, '@girlsfortrump @cinderella2b'),
#  (0.1381942253485741, '@cinderella2b @kamvtv'),
#  (0.1381942253485741, '@kamvtv #us'),
#  (0.1381942253485741, '#us #usa'),
#  (0.13819419133435204, "donald spunktrumpet's"),
#  (0.13819419133435204, "spunktrumpet's former"),
#  (0.13819419133435204, 'former communications'),
#  (0.13819419133435204, 'communications director'),
#  (0.13819419133435204, 'director stephanie'),
#  (0.13819419133435204, 'stephanie cegielski'),
#  (0.13819419133435204, 'cegielski has'),
#  (0.13819419133435204, 'has resigned'),
#  (0.13819419133435204, 'resigned and'),
#  (0.13819419133435204, 'and written'),
#  (0.13819419133435204, 'written this'),
#  (0.13744062867777124, 'surprise @target'),
#  (0.13744062867777124, 'stock drops'),
#  (0.13744062867777124, 'drops since'),
#  (0.13744062867777124, 'since #transgender'),
#  (0.13744062867777124, '#transgender bathroom'),
#  (0.1372288242424594, 'wanted to'),
#  (0.13713696680247622, 'is a'),
#  (0.13698144325257236, 'day #ferguson'),
#  (0.13698144325257236, 'cops told'),
#  (0.13698144325257236, 'told a'),
#  (0.13698144325257236, 'a dirty'),
#  (0.13698144325257236, 'dirty bloody'),
#  (0.13698144325257236, 'bloody lie'),
#  (0.13698144325257236, 'lie via'),
#  (0.13698144325257236, 'via @thedailybeast'),
#  (0.13698144325257236, '@thedailybeast ):'),
#  (0.13603423828201056, 'weapons against'),
#  (0.13603423828201056, 'against kurds'),
#  (0.13603423828201056, 'kurds in'),
#  (0.13603423828201056, 'in #kobane'),
#  (0.13603423828201056, 'alarming isis'),
#  (0.13603423828201056, 'isis uses'),
#  (0.13603423828201056, 'uses chemical'),
#  (0.13603423828201056, '#kobane #savekobane'),
#  (0.13603423828201056, '#savekobane #drwidad'),
#  (0.1349730292075483, 'isis confirms'),
#  (0.1349730292075483, 'confirms leader'),
#  (0.1349730292075483, 'in u'),
#  (-0.13490439977974508, 'in #ottawa'),
#  (0.13484965836272125, "because he's"),
#  (0.1342451239980221, 'from #ferguson'),
#  (0.13406046412008243, 'video hero'),
#  (0.13406046412008243, 'hero sergeant-at-arms'),
#  (0.13406046412008243, 'sergeant-at-arms kevin'),
#  (0.13406046412008243, 'vickers returns'),
#  (0.13406046412008243, 'returns to'),
#  (0.13406046412008243, 'to parliament'),
#  (0.13406046412008243, 'parliament and'),
#  (0.13406046412008243, 'and an'),
#  (0.13406046412008243, 'an incredible'),
#  (0.13406046412008243, 'incredible welcome'),
#  (0.1337819921316743, 'claims he'),
#  (0.1337819921316743, 'russian boy'),
#  (0.1337819921316743, 'boy shocked'),
#  (0.1337819921316743, 'by electricity'),
#  (0.1337819921316743, 'electricity now'),
#  (0.1337819921316743, 'now claims'),
#  (0.1337819921316743, 'has superpowers'),
#  (0.1337819921316743, 'superpowers like'),
#  (0.1337819921316743, 'like magneto'),
#  (0.1334822324462159, 'goes full'),
#  (0.1334822324462159, 'full anti-woman'),
#  (0.1334822324462159, 'anti-woman punishment'),
#  (0.1334822324462159, 'who abort'),
#  (0.13311076767090493, 'ca grand'),
#  (0.13311076767090493, 'grand dragon'),
#  (0.13311076767090493, 'dragon endorses'),
#  (0.13311076767090493, 'clinton on'),
#  (0.13311076767090493, 'on behalf'),
#  (0.13311076767090493, 'behalf of'),
#  (0.13311076767090493, 'the kkk'),
#  (0.13311076767090493, 'kkk #trump2016'),
#  (0.13293820894857608, 'rural region'),
#  (0.13293820894857608, 'region of'),
#  (0.13293820894857608, 'of northern'),
#  (0.13293820894857608, 'northern france'),
#  (0.13293820894857608, 'france searched'),
#  (0.13293820894857608, 'searched in'),
#  (0.13293820894857608, 'in hunt'),
#  (0.13293820894857608, 'hunt for'),
#  (0.13293820894857608, '#charliehebdo gunmen'),
#  (0.13293820894857608, 'gunmen latest'),
#  (0.13293820894857608, 'latest updates'),
#  (-0.13255694419751296, 'list of'),
#  (0.13250587942802158, 'on the'),
#  (-0.13240216804568714, 'joined isis'),
#  (0.1322780406469158, 'the day'),
#  (0.1321848243972161, 'are in'),
#  (0.1321848243972161, 'in full'),
#  (0.1321848243972161, 'full lock'),
#  (0.1321848243972161, 'lock down'),
#  (0.1321848243972161, 'down until'),
#  (0.1321848243972161, 'until further'),
#  (0.1321848243972161, 'further notice'),
#  (0.1321848243972161, 'notice from'),
#  (0.13194683980069233, 'move to'),
#  (0.13194683980069233, 'to canada'),
#  (0.13194683980069233, 'people searching'),
#  (0.13194683980069233, 'searching how'),
#  (0.13194683980069233, 'to move'),
#  (0.13194683980069233, 'canada following'),
#  (0.13194683980069233, 'following trump'),
#  (0.13194683980069233, 'trump clinton'),
#  (0.13194683980069233, 'clinton wins'),
#  (0.13143569184943898, 'trying to'),
#  (0.13126888581277169, 'state leader'),
#  (0.13126888581277169, 'pentagon officials'),
#  (0.13126888581277169, 'officials skeptical'),
#  (0.13126888581277169, 'skeptical over'),
#  (0.13126888581277169, 'over iraqi'),
#  (0.13126888581277169, 'iraqi claims'),
#  (0.13126888581277169, 'of wounded'),
#  (0.13126888581277169, 'wounded islamic'),
#  (0.13126888581277169, 'leader #isis'),
#  (0.13101138125270606, 'at paris'),
#  (0.13101138125270606, 'paris store'),
#  (0.13101138125270606, 'hostage-taker at'),
#  (0.13101138125270606, 'store demands'),
#  (0.13101138125270606, 'demands release'),
#  (0.13101138125270606, 'of #kouachibrothers'),
#  (0.13101138125270606, '#kouachibrothers police'),
#  (0.13101138125270606, 'police union'),
#  (0.13101138125270606, 'union spokesman'),
#  (0.13101138125270606, 'spokesman says'),
#  (0.13053086411146597, 'starve the'),
#  (0.13053086411146597, 'the beasts'),
#  (0.13053086411146597, 'beasts destroying'),
#  (0.13053086411146597, 'destroying our'),
#  (0.13053086411146597, 'our #civilsociety'),
#  (0.13053086411146597, '#civilsociety #target'),
#  (0.13053086411146597, '#target stock'),
#  (0.13053086411146597, 'sinks 1.5'),
#  (0.13026881347092636, 'passenger wears'),
#  (0.13026881347092636, 'wears personal'),
#  (0.13026881347092636, 'personal protective'),
#  (0.13026881347092636, 'protective equipment'),
#  (0.13026881347092636, 'equipment ppe'),
#  (0.13026881347092636, 'ppe for'),
#  (0.13026881347092636, 'flight at'),
#  (0.13026881347092636, 'dulles #ebola'),
#  (0.1299670170056838, 'muslim democrat'),
#  (-0.12988690704574102, 'malaysia airlines'),
#  (0.12958572172384356, 'viral video'),
#  (0.12958572172384356, 'video prankster'),
#  (0.12958572172384356, 'prankster @joshpalerlin'),
#  (0.12958572172384356, '@joshpalerlin gave'),
#  (0.12958572172384356, 'gave homeless'),
#  (0.12958572172384356, 'homeless man'),
#  (0.12958572172384356, 'man 100'),
#  (0.12958572172384356, '100 was'),
#  (0.12958572172384356, 'was shocked'),
#  (0.12958572172384356, 'by results'),
#  (0.12957505526810056, 'meet kevin'),
#  (0.12957505526810056, 'vickers the'),
#  (0.12957505526810056, 'the hero'),
#  (0.12957505526810056, 'the parliament'),
#  (0.12957505526810056, 'hill gunman'),
#  (0.12957505526810056, 'gunman #ottawashooting'),
#  (0.12956146725466405, 'some form'),
#  (0.12956146725466405, 'of punishment'),
#  (-0.1289506834101898, 'for the'),
#  (0.12843397615941055, 'was victoria'),
#  (0.12843397615941055, 'woodhull in'),
#  (0.12843397615941055, 'in 1872'),
#  (-0.12809853560175366, 'to end'),
#  (-0.12798136507474073, 'with a'),
#  (-0.1278757609951708, 'been arrested'),
#  (0.12786198136999197, 'orlando shooter'),
#  (0.12771247356935328, "target's stock"),
#  (0.12713866892346248, 'the insane'),
#  (0.12713866892346248, 'insane reason'),
#  (0.12713866892346248, 'reason why'),
#  (0.12713866892346248, 'why chinese'),
#  (0.12713866892346248, 'chinese drivers'),
#  (0.12713866892346248, 'drivers intentionally'),
#  (0.12713866892346248, 'intentionally kill'),
#  (0.12713866892346248, 'kill pedestrians'),
#  (0.12713866892346248, 'pedestrians they'),
#  (0.12713866892346248, 'they hit'),
#  (0.12713866892346248, 'hit via'),
#  (0.12713866892346248, 'via @slate'),
#  (0.12652402450023886, 'robbery #ferguson'),
#  (0.12633740473165667, 'it was'),
#  (0.12583507946689512, 'over its'),
#  (0.12489008560119565, 'obama is'),
#  (-0.12484298228686827, 'amber alert'),
#  (-0.12472008661245289, "banksy's response"),
#  (-0.1242903108622744, 'that he'),
#  (0.12419479990660019, 'out the'),
#  (0.12419479990660019, 'hour five'),
#  (0.12419479990660019, 'five of'),
#  (0.12419479990660019, 'your road'),
#  (0.12419479990660019, 'road trip'),
#  (0.12419479990660019, 'trip time'),
#  (0.12419479990660019, 'to break'),
#  (0.12419479990660019, 'break out'),
#  (0.12419479990660019, 'the s'),
#  (0.12419479990660019, 's pen'),
#  (0.12418631836782197, 'meat when'),
#  (0.12418631836782197, 'one third'),
#  (0.12418631836782197, 'third of'),
#  (0.12418631836782197, 'vegetarians eat'),
#  (0.12418631836782197, 'they get'),
#  (0.12418631836782197, 'get drunk'),
#  (-0.12411603592916168, 'war memorial'),
#  (0.12384339026570265, 'of isis'),
#  (-0.12353921580729021, 'mass grave'),
#  (0.12323982267523641, 'to avoid'),
#  (0.12299328640928031, '#charliehebdo attack'),
#  (0.12275081711549357, 'the no'),
#  (0.12275081711549357, '1 killer'),
#  (0.12275081711549357, 'killer of'),
#  (0.12275081711549357, 'americans these'),
#  (0.12275081711549357, 'these rankings'),
#  (0.12275081711549357, 'rankings have'),
#  (0.12275081711549357, 'have changed'),
#  (0.12275081711549357, 'changed little'),
#  (0.12275081711549357, 'little over'),
#  (0.12275081711549357, 'the years'),
#  (0.12273014536128926, 'in usa'),
#  (0.12273014536128926, 'usa in'),
#  (0.12273014536128926, '2016 through'),
#  (0.12273014536128926, 'through june'),
#  (0.12273014536128926, 'june 15'),
#  (0.12239901535301806, 'in what'),
#  (0.12239901535301806, 'what world'),
#  (0.12239901535301806, 'world do'),
#  (0.12239901535301806, 'you let'),
#  (0.12239901535301806, 'let a'),
#  (0.12239901535301806, 'a cop'),
#  (0.12239901535301806, 'cop who'),
#  (0.12239901535301806, 'killed someone'),
#  (0.12239901535301806, 'someone leave'),
#  (0.12239901535301806, 'leave town'),
#  (0.12239901535301806, 'town #ferguson'),
#  (-0.12167268892617131, 'high school'),
#  (0.12107648525025444, 'when they'),
#  (0.12074000342762646, 'the 5p'),
#  (0.12074000342762646, 'plastic bag'),
#  (0.12069217308190587, 'soldier at'),
#  (-0.11994413736036745, 'tribute to'),
#  (0.11951413883009028, '@berniesanders is'),
#  (0.11951413883009028, 'is pulling'),
#  (0.11951413883009028, 'pulling magic'),
#  (0.11951413883009028, 'magic tricks'),
#  (0.11951413883009028, 'tricks out'),
#  (0.11951413883009028, 'a hat'),
#  (0.11951413883009028, 'hat in'),
#  (0.11951413883009028, 'nevada we'),
#  (0.11951413883009028, 'just officially'),
#  (0.11951413883009028, 'officially won'),
#  (0.11940412051145173, 'breaking at'),
#  (0.11940412051145173, 'least 20'),
#  (0.11940412051145173, '20 shots'),
#  (0.11940412051145173, 'shots have'),
#  (0.11940412051145173, 'been fired'),
#  (0.11940412051145173, 'fired in'),
#  (0.11940412051145173, 'parliament in'),
#  (0.11940412051145173, 'ottawa according'),
#  (0.11925737428862455, 'purple pain'),
#  (0.11925737428862455, 'pain landmarks'),
#  (0.11925737428862455, 'across globe'),
#  (0.11925737428862455, 'globe light'),
#  (0.11925737428862455, 'light up'),
#  (0.11925737428862455, 'in fitting'),
#  (0.11925737428862455, 'fitting prince'),
#  (0.11925737428862455, 'prince tributes'),
#  (0.11925737428862455, 'tributes #ripprince'),
#  (0.11918868495875308, 'uniformed soldier'),
#  (0.11877711555773525, 'wilson is'),
#  (0.11877711555773525, 'urgent darren'),
#  (0.11877711555773525, 'shot mike'),
#  (0.11877711555773525, 'brown #ferguson'),
#  (-0.11846342333480009, 'was shot'),
#  (0.1183875726504264, 'all in'),
#  (0.1183875726504264, 'in purple'),
#  (0.1183875726504264, 'purple memorials'),
#  (0.1183875726504264, 'memorials and'),
#  (0.1183875726504264, 'and landmarks'),
#  (0.1183875726504264, 'across the'),
#  (0.1183875726504264, 'the globe'),
#  (0.1183875726504264, 'globe honor'),
#  (0.1183875726504264, 'honor #prince'),
#  (0.1183875726504264, '#prince after'),
#  (0.11823319686853753, 'breaking isis'),
#  (0.11823319686853753, 'al-baghdadi critically'),
#  (0.11823319686853753, 'critically wounded'),
#  (0.11823319686853753, 'wounded after'),
#  (0.11823319686853753, 'after coalition'),
#  (0.11823319686853753, 'coalition airstrikes'),
#  (0.11823319686853753, 'airstrikes near'),
#  (0.11823319686853753, 'near mosul'),
#  (-0.11810426838053956, 'audio of'),
#  (0.11801212068667973, 'want to'),
#  (0.1179773512146421, 'very good'),
#  (0.1179773512146421, 'good on'),
#  (0.1179773512146421, '#putin coup'),
#  (0.1179773512146421, 'coup by'),
#  (0.1179773512146421, 'by @coalsonr'),
#  (0.1179773512146421, '@coalsonr three'),
#  (0.1179773512146421, 'three scenarios'),
#  (0.1179773512146421, 'scenarios for'),
#  (0.1179773512146421, 'a succession'),
#  (0.1179773512146421, 'succession in'),
#  (0.1179773512146421, 'in russia'),
#  (0.1179773512146421, 'russia via'),
#  (0.1179773512146421, 'via @rferl'),
#  (0.11793695904795853, 'jenner will'),
#  (0.11793695904795853, 'will pose'),
#  (0.11785982579413025, 'that the'),
#  (0.11782539984958097, 'say isis'),
#  (0.11782539984958097, 'leader wounded'),
#  (0.11772106380762996, 'female peshmerga'),
#  (0.11772106380762996, 'peshmerga warrior'),
#  (0.11772106380762996, 'warrior rehana'),
#  (0.11772106380762996, 'rehana credited'),
#  (0.11772106380762996, 'credited with'),
#  (0.11772106380762996, 'with killing'),
#  (0.11772106380762996, 'killing 100'),
#  (0.11772106380762996, '100 isis'),
#  (0.11772106380762996, 'isis scumbags'),
#  (0.11772106380762996, 'scumbags reportedly'),
#  (0.11772106380762996, 'reportedly captured'),
#  (0.11772106380762996, 'captured beheaded'),
#  (0.11772106380762996, 'beheaded #rip'),
#  (0.11772099094507156, 'update hostages'),
#  (0.11772099094507156, 'hostages fleeing'),
#  (0.11772099094507156, 'fleeing #sydney'),
#  (0.11772099094507156, '#sydney cafe'),
#  (0.11772099094507156, 'cafe held'),
#  (0.11772099094507156, 'held by'),
#  (0.11772099094507156, 'by iranian'),
#  (0.11772099094507156, 'iranian gunman'),
#  (0.11772099094507156, 'gunman as'),
#  (0.11772099094507156, 'as explosions'),
#  (0.11772099094507156, 'explosions gunshots'),
#  (0.11772099094507156, 'gunshots are'),
#  (0.11772099094507156, 'are heard'),
#  (0.1175172131059958, 'for women'),
#  (0.11737625708996824, 'in 2009'),
#  (0.11737625708996824, 'police beat'),
#  (0.11737625708996824, 'charged him'),
#  (0.11737625708996824, 'him for'),
#  (-0.1173619052146368, "leo's first"),
#  (-0.1173619052146368, 'first sag'),
#  (-0.1173619052146368, 'sag #sagawards'),
#  (-0.11736188850887427, 'some #wednesdaywisdom'),
#  (-0.11736188850887427, '#wednesdaywisdom from'),
#  (-0.11736188850887427, 'from #thelionking'),
#  (-0.1173618853656539, "it wasn't"),
#  (-0.1173618853656539, "wasn't even"),
#  (-0.1173618853656539, 'even close'),
#  (0.11725525031594491, 'he was'),
#  (0.11716607880665067, 'attack on'),
#  (-0.11679043972475438, 'to a'),
#  (-0.1163159865526844, 'has died'),
#  (0.11614861620640289, 'update #ferguson'),
#  (0.11614861620640289, 'release stills'),
#  (0.11614861620640289, 'stills from'),
#  (0.11614861620640289, 'from convenience'),
#  (0.11614861620640289, 'convenience store'),
#  (0.11614861620640289, 'store footage'),
#  (0.11614861620640289, 'footage showing'),
#  (0.11614861620640289, 'showing robbery'),
#  (0.11614323967800967, 'to be'),
#  (0.11555046965775848, 'to avenge'),
#  (0.11555046965775848, 'avenge her'),
#  (0.11555046965775848, 'her sons'),
#  (0.11555046965775848, 'sons murder'),
#  (0.11497519456732383, 'have an'),
#  (0.11494702295004447, 'mothers revenge'),
#  (0.11494702295004447, 'revenge afghan'),
#  (0.11494702295004447, '25 #taliban'),
#  (0.11494702295004447, '#taliban militants'),
#  (0.11494702295004447, 'militants after'),
#  (0.11494702295004447, 'after son'),
#  (0.11494702295004447, 'son shot'),
#  (0.11477041141797972, 'a man'),
#  (0.11466389515845432, 'boycotting target'),
#  (0.11366054158713151, 'reported wounded'),
#  (0.11366054158713151, 'john reported'),
#  (-0.11291830550303535, 'donna douglas'),
#  (0.11223992309298958, 'good news'),
#  (0.1117552243952413, 'is real'),
#  (0.11167748507295515, 'dear @hillaryclinton'),
#  (0.11167748507295515, "@hillaryclinton you're"),
#  (0.11167748507295515, "you're not"),
#  (0.11167748507295515, '1st woman'),
#  (0.11167748507295515, 'woman presidential'),
#  (0.11167748507295515, 'candidate victoria'),
#  (0.11167748507295515, 'woodhull is'),
#  (0.11167748507295515, 'is look'),
#  (0.11167748507295515, 'look @realdonaldtrump'),
#  (0.11131740772031835, 'people in'),
#  (0.11131740772031835, 'in china'),
#  (0.11131740772031835, 'china claim'),
#  (0.11131740772031835, 'claim they'),
#  (0.11131740772031835, 'have seen'),
#  (0.11131740772031835, 'seen a'),
#  (0.11131740772031835, 'a floating'),
#  (0.11131740772031835, 'floating city'),
#  (0.11131740772031835, 'the sky'),
#  (0.1105988379084129, 'was not'),
#  (0.1104608932004931, 'pray for'),
#  (0.1104608932004931, 'for parents'),
#  (0.1104608932004931, 'parents and'),
#  (0.1104608932004931, 'and school'),
#  (0.1104608932004931, 'school leadership'),
#  (0.1104608932004931, 'leadership to'),
#  (0.1104608932004931, 'have wisdom'),
#  (0.1104608932004931, 'wisdom to'),
#  (0.1104608932004931, 'to refuse'),
#  (0.1104608932004931, 'refuse these'),
#  (0.1104608932004931, 'these after'),
#  (0.1104608932004931, 'after school'),
#  (0.1104608932004931, 'school satan'),
#  (0.1104608932004931, 'satan clubs'),
#  (0.11021187768312093, 'keith richards'),
#  (0.11021187768312093, 'richards once'),
#  (0.11021187768312093, 'once pulled'),
#  (0.11021187768312093, 'pulled a'),
#  (0.11021187768312093, 'a knife'),
#  (0.11021187768312093, 'knife on'),
#  (0.11021187768312093, 'on donald'),
#  (0.11021187768312093, 'trump says'),
#  (0.11021187768312093, 'says rolling'),
#  (0.11021187768312093, 'rolling stones'),
#  (0.11021187768312093, 'stones ex-event'),
#  (0.11021187768312093, 'ex-event promoter'),
#  (0.11017858559659816, 'obama to'),
#  (0.11017858559659816, 'skip nancy'),
#  (0.10989505577558589, 'petrol station'),
#  (0.10960230945602127, 'breaking michael'),
#  (0.10960230945602127, 'michael zehaf-bebeau'),
#  (0.10960230945602127, 'zehaf-bebeau had'),
#  (0.10960230945602127, 'had been'),
#  (0.10960230945602127, 'been designated'),
#  (0.10960230945602127, 'designated high-risk'),
#  (0.10960230945602127, 'high-risk traveller'),
#  (0.10960230945602127, 'traveller by'),
#  (0.10960230945602127, 'by cdn'),
#  (0.10960230945602127, 'cdn govt'),
#  (0.10960230945602127, 'govt which'),
#  (0.10960230945602127, 'which confiscated'),
#  (0.10960230945602127, 'confiscated his'),
#  (0.10960230945602127, 'his passport'),
#  (0.10960229562996304, 'clinton hides'),
#  (0.10960229562996304, 'hides failing'),
#  (0.10960229562996304, 'failing health'),
#  (0.10960229562996304, 'health full'),
#  (0.10960229562996304, 'full disclosure'),
#  (0.10960229562996304, 'disclosure now'),
#  (0.10960229562996304, 'now covert'),
#  (0.10960229562996304, 'covert doctors'),
#  (0.10960229562996304, 'doctors and'),
#  (0.10960229562996304, 'and nurses'),
#  (0.10960229562996304, 'nurses via'),
#  (0.10960229562996304, 'via @mailonline'),
#  (0.10960229562996304, '@mailonline #maga'),
#  (0.10960229562996304, '#maga @realdonaldtrump'),
#  (0.10932968502608886, 'boycott crosses'),
#  (0.10932968502608886, 'crosses 1'),
#  (0.10932968502608886, '1 million'),
#  (0.10932968502608886, 'million signers'),
#  (0.10932968502608886, 'signers stock'),
#  (0.10932968502608886, 'sinks by'),
#  (0.10932968502608886, 'by 1.5'),
#  (0.10932968502608886, 'billion breitbart'),
#  (0.10924195629637465, 'by a'),
#  (-0.10855927503817919, 'manager bans'),
#  (0.1084597515603864, 'report nasty'),
#  (0.1084597515603864, 'nasty ios'),
#  (0.1084597515603864, 'bug could'),
#  (0.1084597515603864, 'could erase'),
#  (0.1084597515603864, 'erase your'),
#  (0.10827887196655406, 'to trump'),
#  (0.10827887196655406, 'trump voters'),
#  (0.10827887196655406, 'voters from'),
#  (0.10798849104195121, 'destruction of'),
#  (0.10787155839099465, 'unarmed teenager'),
#  (-0.1077842669579249, 'kkk wednesday'),
#  (-0.1069140610387748, 'david haines'),
#  (-0.1068237525654178, 'arrested overnight'),
#  (-0.1068237525654178, 'overnight in'),
#  (-0.1068237525654178, '78 not'),
#  (-0.1068237525654178, 'not 31'),
#  (-0.1068237525654178, '31 arrested'),
#  (0.10655463953822256, 'gay muslim'),
#  (-0.10640301931233871, 'islamic tribunal'),
#  (-0.10594710060010697, "world's largest"),
#  (-0.10579317225643703, 'saudi cleric'),
#  (0.10577267969491995, 'one person'),
#  (0.10577267969491995, 'person shot'),
#  (0.10577267969491995, 'shot outside'),
#  (0.10577267969491995, 'outside centre'),
#  (0.10577267969491995, 'block a'),
#  (0.10577267969491995, 'a second'),
#  (0.10577267969491995, 'second wounded'),
#  (0.10577267969491995, 'wounded inside'),
#  (0.10577267969491995, 'hill shooting'),
#  (-0.10534878205446005, 'arrested in'),
#  (0.10531415354227883, 'a box'),
#  (0.10517678242767706, 'the orlando'),
#  (-0.10495710400328892, 'pope francis'),
#  (0.10486847594972606, 'fix society'),
#  (0.10486847594972606, 'a transgender'),
#  (0.10486847594972606, 'transgender 17'),
#  (0.10486847594972606, 'left a'),
#  (0.10486847594972606, 'a suicide'),
#  (0.10486847594972606, 'tumblr pleading'),
#  (0.10486847594972606, 'pleading fix'),
#  (-0.10485382808113132, 'via @nytopinion'),
#  (0.10482510467987767, 'the teletubby'),
#  (0.10482510467987767, 'teletubby sun'),
#  (0.10482510467987767, 'sun baby'),
#  (0.10482510467987767, 'baby is'),
#  (0.10482510467987767, 'years old'),
#  (0.10482510467987767, 'old now'),
#  (0.10462784219741053, '#charliehebdo shooting'),
#  (-0.10423152308675557, 'after 40'),
#  (0.10418150092784954, 'purple in'),
#  (0.10418150092784954, 'in honor'),
#  (0.10418150092784954, 'honor of'),
#  (0.10418150092784954, 'when your'),
#  (0.10418150092784954, 'your two'),
#  (0.10418150092784954, 'two favorite'),
#  (0.10418150092784954, 'favorite landmarks'),
#  (0.10418150092784954, 'landmarks ...'),
#  (0.10418150092784954, '... go'),
#  (0.10418150092784954, 'go purple'),
#  (0.10418150092784954, 'world missing'),
#  (0.10418150092784954, 'missing prince'),
#  (0.10418150092784954, 'prince ...'),
#  (0.10418150092784954, '... beautiful'),
#  (0.1041156159333151, 'this russian'),
#  (0.1041156159333151, 'russian kid'),
#  (0.1041156159333151, 'kid got'),
#  (0.1041156159333151, 'got zapped'),
#  (0.1041156159333151, 'zapped by'),
#  (0.1041156159333151, 'a faulty'),
#  (0.1041156159333151, 'faulty electrical'),
#  (0.1041156159333151, 'electrical wire'),
#  (0.1041156159333151, 'wire and'),
#  (0.1041156159333151, 'and now'),
#  (0.1041156159333151, "now he's"),
#  (0.1041156159333151, 'a real-life'),
#  (0.1041156159333151, 'real-life magneto'),
#  (-0.10342354509931313, 'fanged deer'),
#  (0.10338612180497374, '#isis used'),
#  (0.10338612180497374, 'used chemical'),
#  (0.10338612180497374, 'weapons in'),
#  (0.10338612180497374, 'in #kobani'),
#  (0.10338612180497374, '#kobani against'),
#  (0.10338612180497374, 'against civilian'),
#  (0.10338612180497374, 'civilian #kurds'),
#  ...]

# %%
def custom_vectors_generation(texts, tokens):
    bigram_vectors = []
    for text in texts:
        bigrams = text2bigrams(text)

        init_vec = [0.0 for _ in range(len(tokens) + 1)]
        for bgr in bigrams:
            if bgr in tokens:
                idx = tokens.index(bgr)
                init_vec[idx] = 1.0
            else:
                init_vec[-1] = 1.0
        bigram_vectors.append(init_vec)
    
    return bigram_vectors

def custom_vectors_generation_v2(texts, tokens):
    bigram_vectors = []
    for text in texts:
        bigrams = text2bigrams(text)

        init_vec = [0.0 for _ in range(len(tokens))]
        for bgr in bigrams:
            if bgr in tokens:
                idx = tokens.index(bgr)
                init_vec[idx] = 1.0
        bigram_vectors.append(init_vec)
    
    return bigram_vectors

start = 100
f1s = []
for i in range(100):
    n_token = start + 100*i
    print(f"Using first {n_token} Tokens ....")
    picked_tokens = [t[1] for t in coefs_and_features[:n_token]]
    
    vectors = custom_vectors_generation(texts, picked_tokens)
#     vectors = custom_vectors_generation_v2(texts, picked_tokens)
    
    train_vectors = np.array([vectors[i] for i, d in data.iterrows() if d['tvt2'] == 'training'])
    val_vectors = np.array([vectors[i] for i, d in data.iterrows() if d['tvt2'] == 'validation'])
    
    model = SKLearnClassification(svm, "Support Vector Machine")
    model.train(train_vectors, train_labels, "Twitter15", logs=False)

    preds = model.predict(val_vectors)
    conf_mat = ConfusionMatrix(
        labels=val_labels,
        predictions=preds,
        binary=True
    )
    conf_mat.evaluate(logs=False)
    f1s.append(conf_mat.f1)
# Out:
# Using first 100 Tokens ....
# Using first 200 Tokens ....
# Using first 300 Tokens ....
# Using first 400 Tokens ....
# Using first 500 Tokens ....
# Using first 600 Tokens ....
# Using first 700 Tokens ....
# Using first 800 Tokens ....
# Using first 900 Tokens ....
# Using first 1000 Tokens ....
# Using first 1100 Tokens ....
# Using first 1200 Tokens ....
# Using first 1300 Tokens ....
# Using first 1400 Tokens ....
# Using first 1500 Tokens ....
# Using first 1600 Tokens ....
# Using first 1700 Tokens ....
# Using first 1800 Tokens ....
# Using first 1900 Tokens ....
# Using first 2000 Tokens ....
# Using first 2100 Tokens ....
# Using first 2200 Tokens ....
# Using first 2300 Tokens ....
# Using first 2400 Tokens ....
# Using first 2500 Tokens ....
# Using first 2600 Tokens ....
# Using first 2700 Tokens ....
# Using first 2800 Tokens ....
# Using first 2900 Tokens ....
# Using first 3000 Tokens ....
# Using first 3100 Tokens ....
# Using first 3200 Tokens ....
# Using first 3300 Tokens ....
# Using first 3400 Tokens ....
# Using first 3500 Tokens ....
# Using first 3600 Tokens ....
# Using first 3700 Tokens ....
# Using first 3800 Tokens ....
# Using first 3900 Tokens ....
# Using first 4000 Tokens ....
# Using first 4100 Tokens ....
# Using first 4200 Tokens ....
# Using first 4300 Tokens ....
# Using first 4400 Tokens ....
# Using first 4500 Tokens ....
# Using first 4600 Tokens ....
# Using first 4700 Tokens ....
# Using first 4800 Tokens ....
# Using first 4900 Tokens ....
# Using first 5000 Tokens ....
# Using first 5100 Tokens ....
# Using first 5200 Tokens ....
# Using first 5300 Tokens ....
# Using first 5400 Tokens ....
# Using first 5500 Tokens ....
# Using first 5600 Tokens ....
# Using first 5700 Tokens ....
# Using first 5800 Tokens ....
# Using first 5900 Tokens ....
# Using first 6000 Tokens ....
# Using first 6100 Tokens ....
# Using first 6200 Tokens ....
# Using first 6300 Tokens ....
# Using first 6400 Tokens ....
# Using first 6500 Tokens ....
# Using first 6600 Tokens ....
# Using first 6700 Tokens ....
# Using first 6800 Tokens ....
# Using first 6900 Tokens ....
# Using first 7000 Tokens ....
# Using first 7100 Tokens ....
# Using first 7200 Tokens ....
# Using first 7300 Tokens ....
# Using first 7400 Tokens ....
# Using first 7500 Tokens ....
# Using first 7600 Tokens ....
# Using first 7700 Tokens ....
# Using first 7800 Tokens ....
# Using first 7900 Tokens ....
# Using first 8000 Tokens ....
# Using first 8100 Tokens ....
# Using first 8200 Tokens ....
# Using first 8300 Tokens ....
# Using first 8400 Tokens ....
# Using first 8500 Tokens ....
# Using first 8600 Tokens ....
# Using first 8700 Tokens ....
# Using first 8800 Tokens ....
# Using first 8900 Tokens ....
# Using first 9000 Tokens ....
# Using first 9100 Tokens ....
# Using first 9200 Tokens ....
# Using first 9300 Tokens ....
# Using first 9400 Tokens ....
# Using first 9500 Tokens ....
# Using first 9600 Tokens ....
# Using first 9700 Tokens ....
# Using first 9800 Tokens ....
# Using first 9900 Tokens ....
# Using first 10000 Tokens ....

# %%
print(max(f1s))
f1s.index(max(f1s))
# Out:
# 0.5172724253583476
# 87

# %%
import matplotlib.pyplot as plt

x = [i*100 for i in range(len(f1s))]
y = f1s

plt.xlabel("Token/Bigram used")
plt.ylabel("F1 Score")
plt.plot(x, y)
plt.show()

# %%
import json

best_tokens = [t[1] for t in coefs_and_features[:6100]]
best_tokens[:10]

# with open("../../data/processed/twitter15_best_bigrams.txt", "w") as f:
#     for token in best_tokens:
#         f.write(token + "\n")
# Out:
# ['bathroom policy',
#  'hands up',
#  'wounded in',
#  '5p hell',
#  'hell no',
#  'no #5pbagcharge',
#  'bernie sanders',
#  '#ferguson police',
#  'institutional racism',
#  'transgender bathroom']
